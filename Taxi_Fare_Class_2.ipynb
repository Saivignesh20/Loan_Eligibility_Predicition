# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Akshat Sharma\OneDrive\Desktop\Data Science\Machine learning\Decision Tree\Imarticus Dataset\Decision Tree Project\Dataset 2\Random Forest Project\Dataset\TaxiFare.csv", parse_dates= ["date_time_of_pickup"])

# %%
df = df[5000:10000]
df
# Out:
#      unique_id  amount       date_time_of_pickup  longitude_of_pickup  \
# 5000   39:00.0    11.0 2013-04-19 17:39:00+00:00           -73.985905
# 5001   28:00.0    10.9 2011-04-15 21:28:00+00:00           -73.959258
# 5002   03:00.0     6.0 2013-08-22 20:03:00+00:00           -73.974267
# 5003   13:00.0     6.0 2014-07-19 13:13:00+00:00           -73.976727
# 5004   38:00.0    10.5 2011-07-02 10:38:00+00:00           -73.921262
# ...        ...     ...                       ...                  ...
# 9995   44:00.0    11.7 2011-10-26 10:44:00+00:00           -73.988277
# 9996   37:00.0     5.7 2011-12-16 15:37:00+00:00           -74.002112
# 9997   47:17.0    12.0 2013-11-16 22:47:17+00:00           -73.992093
# 9998   38:00.0     6.5 2010-01-28 11:38:00+00:00           -73.992548
# 9999   48:44.0    10.5 2011-07-05 06:48:44+00:00           -73.978400
#
#       latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# ...

# %%
import numpy as np
import pandas as pd
import requests  # Import the 'requests' module

# Replace 'YOUR_API_KEY' with your actual MapQuest API key
api_key = 'czXKotOY1IWAObwbveGAZejyfTcvCWjW'

# Initialize an empty list to store distances
distances = []

# Iterate through the DataFrame rows and calculate distances
for index, row in df.iterrows():
    pickup = f"{row['latitude_of_pickup']},{row['longitude_of_pickup']}"
    dropoff = f"{row['latitude_of_dropoff']},{row['longitude_of_dropoff']}"
    
    url = f"https://www.mapquestapi.com/directions/v2/route?key={api_key}&from={pickup}&to={dropoff}&routeType=fastest"
    
    try:
        response = requests.get(url)
        response_data = response.json()

        if "route" in response_data and len(response_data["route"]["legs"]) > 0:
            distance = response_data["route"]["distance"]
            distances.append(distance)
            print(f"Distance for index {index}: {distance} miles")
        else:
            break
    except:
        distances.append(np.nan)
# Out:
# Distance for index 5000: 2.1965 miles
# Distance for index 5001: 3.9693 miles
# Distance for index 5002: 0.8799 miles
# Distance for index 5003: 0.9463 miles
# Distance for index 5004: 3.2175 miles
# Distance for index 5005: 2.0487 miles
# Distance for index 5006: 2.4352 miles
# Distance for index 5007: 3.343 miles
# Distance for index 5008: 0.6444 miles
# Distance for index 5009: 4.4627 miles
# Distance for index 5010: 1.2086 miles
# Distance for index 5011: 0.6624 miles
# Distance for index 5012: 1.2079 miles
# Distance for index 5013: 3.1044 miles
# Distance for index 5014: 0.4051 miles
# Distance for index 5015: 17.9228 miles
# Distance for index 5016: 7.2328 miles
# Distance for index 5017: 0.9283 miles
# Distance for index 5018: 0 miles
# Distance for index 5019: 2.3954 miles
# Distance for index 5020: 1.0824 miles
# Distance for index 5021: 2.4786 miles
# Distance for index 5022: 1.7075 miles
# Distance for index 5023: 0 miles
# Distance for index 5024: 1.2583 miles
# ...

# %%
len(distances)
# Out:
# 686

# %%
df_2 = df.loc[5000:5685]
df_2
# Out:
#      unique_id  amount       date_time_of_pickup  longitude_of_pickup  \
# 5000   39:00.0    11.0 2013-04-19 17:39:00+00:00           -73.985905
# 5001   28:00.0    10.9 2011-04-15 21:28:00+00:00           -73.959258
# 5002   03:00.0     6.0 2013-08-22 20:03:00+00:00           -73.974267
# 5003   13:00.0     6.0 2014-07-19 13:13:00+00:00           -73.976727
# 5004   38:00.0    10.5 2011-07-02 10:38:00+00:00           -73.921262
# ...        ...     ...                       ...                  ...
# 5681   33:34.0    13.7 2009-06-17 15:33:34+00:00           -74.009036
# 5682   06:08.0     4.1 2011-02-08 00:06:08+00:00           -74.006537
# 5683   50:00.0     4.9 2011-04-08 20:50:00+00:00           -73.978268
# 5684   23:24.0     7.0 2013-12-09 23:23:24+00:00           -73.977115
# 5685   48:20.0     4.1 2010-12-10 07:48:20+00:00           -73.990241
#
#       latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# ...

# %%
df_2["distance_in_miles"] = distances
# Out:
# C:\Users\Akshat Sharma\AppData\Local\Temp\ipykernel_20556\3260940928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2["distance_in_miles"] = distances

# %%
df_2.to_csv(r"C:\Users\Akshat Sharma\OneDrive\Desktop\Data Science\Machine learning\Decision Tree\Imarticus Dataset\Decision Tree Project\Dataset 2\Random Forest Project\Dataset\df2.csv", index=False)

# %%
df_1 = df.loc[5815:10000]
df_1
# Out:
#      unique_id  amount       date_time_of_pickup  longitude_of_pickup  \
# 5815   44:19.0     9.7 2009-02-12 10:44:19+00:00           -73.971844
# 5816   41:00.0     4.1 2009-04-19 11:41:00+00:00           -73.976367
# 5817   15:00.0     5.7 2009-11-19 18:15:00+00:00           -74.008497
# 5818   26:00.0     8.0 2013-02-01 09:26:00+00:00           -73.981135
# 5819   27:47.0     4.0 2013-06-07 03:27:47+00:00           -74.005265
# ...        ...     ...                       ...                  ...
# 9995   44:00.0    11.7 2011-10-26 10:44:00+00:00           -73.988277
# 9996   37:00.0     5.7 2011-12-16 15:37:00+00:00           -74.002112
# 9997   47:17.0    12.0 2013-11-16 22:47:17+00:00           -73.992093
# 9998   38:00.0     6.5 2010-01-28 11:38:00+00:00           -73.992548
# 9999   48:44.0    10.5 2011-07-05 06:48:44+00:00           -73.978400
#
#       latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# ...

# %%
import numpy as np
import pandas as pd
import requests  # Import the 'requests' module

# Replace 'YOUR_API_KEY' with your actual MapQuest API key
api_key = 'tYGSxDssMwff5hQhTIKWlHatiOhiDXPs'

# Initialize an empty list to store distances
distances_1 = []

# Iterate through the DataFrame rows and calculate distances
for index, row in df_1.iterrows():
    pickup = f"{row['latitude_of_pickup']},{row['longitude_of_pickup']}"
    dropoff = f"{row['latitude_of_dropoff']},{row['longitude_of_dropoff']}"
    
    url = f"https://www.mapquestapi.com/directions/v2/route?key={api_key}&from={pickup}&to={dropoff}&routeType=fastest"
    
    try:
        response = requests.get(url)
        response_data = response.json()

        if "route" in response_data and len(response_data["route"]["legs"]) > 0:
            distance = response_data["route"]["distance"]
            distances_1.append(distance)
            print(f"Distance for index {index}: {distance} miles")
        else:
            print(f"No route data for index {index}")
    except:
        distances_1.append(np.nan)
# Out:
# Distance for index 5815: 1.6292 miles
# Distance for index 5816: 0.8494 miles
# Distance for index 5819: 0.5387 miles
# Distance for index 5820: 8.6085 miles
# Distance for index 5821: 1.5969 miles
# Distance for index 5822: 2.4811 miles
# Distance for index 5823: 1.3136 miles
# Distance for index 5824: 1.1924 miles
# Distance for index 5825: 0.5611 miles
# Distance for index 5826: 4.7479 miles
# Distance for index 5827: 3.7618 miles
# Distance for index 5828: 1.1129 miles
# Distance for index 5829: 11.0952 miles
# Distance for index 5830: 1.0818 miles
# Distance for index 5831: 1.1328 miles
# Distance for index 5832: 0.9258 miles
# Distance for index 5833: 1.7044 miles
# Distance for index 5834: 1.6125 miles
# Distance for index 5835: 1.2452 miles
# Distance for index 5836: 2.4327 miles
# Distance for index 5837: 1.2309 miles
# Distance for index 5838: 0.6593 miles
# Distance for index 5839: 1.3614 miles
# Distance for index 5840: 0.5605 miles
# ...

# %%
len(distances_1)
# Out:
# 4314

# %%
pd.merge

# %%
df_1["distance_in_miles"] = distances_1
df_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_1["distance_in_miles"] = distances_1
#       2 df_1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
# ...

# %%
df_1.to_csv(r"C:\Users\Akshat Sharma\OneDrive\Desktop\Data Science\Machine learning\Decision Tree\Imarticus Dataset\Decision Tree Project\Dataset 2\Random Forest Project\Dataset\df515.csv", index=False)
